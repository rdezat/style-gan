# %% [markdown]
# <a href="https://colab.research.google.com/github/rdezat/style-gan/blob/master/style_gan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clonem el repositori que conté el codi
# !git clone https://github.com/rdezat/style-gan.git
# Out:
# Cloning into 'style-gan'...
# remote: Enumerating objects: 597, done.
# remote: Counting objects: 100% (597/597), done.
# remote: Compressing objects: 100% (564/564), done.
# remote: Total 1327 (delta 73), reused 523 (delta 26), pack-reused 730
# Receiving objects: 100% (1327/1327), 128.74 MiB | 12.30 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
# %cd /content/style-gan
# !git pull
# Out:
# /content/style-gan
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 12 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (12/12), done.
# From https://github.com/rdezat/style-gan
#    7db5f87..1219545  master     -> origin/master
# Updating 7db5f87..1219545
# Fast-forward
#  models/pollock/discriminator_epoch_100.pth  | Bin 0 -> 11068572 bytes
#  models/pollock/discriminator_epoch_1200.pth | Bin 0 -> 11068572 bytes
#  models/pollock/discriminator_epoch_400.pth  | Bin 0 -> 11068572 bytes
#  models/pollock/discriminator_epoch_800.pth  | Bin 0 -> 11068572 bytes
#  models/pollock/generator_epoch_100.pth      | Bin 0 -> 1170918 bytes
#  models/pollock/generator_epoch_1200.pth     | Bin 0 -> 1170918 bytes
#  models/pollock/generator_epoch_400.pth      | Bin 0 -> 1170914 bytes
#  models/pollock/generator_epoch_800.pth      | Bin 0 -> 1170914 bytes
# ...

# %%
# Executem l'arxiu main.py per l'entrenament amb el conjunt de dades de Pollock amb els paràmetres de per defecte.
# %cd /content
# !python style-gan/main.py train --dataset_name pollock --n_epochs 2000 --decay_epoch 50 --epoch 1600 --batch-size 4 --cuda 1
# Out:
# Streaming output truncated to the last 5000 lines.
# [Epoch 1737/2000] [Batch 0/19] [D loss: 0.000163] [G loss: 1.013505]
# [Epoch 1737/2000] [Batch 1/19] [D loss: 0.000248] [G loss: 1.029574]
# [Epoch 1737/2000] [Batch 2/19] [D loss: 0.000184] [G loss: 1.014529]
# [Epoch 1737/2000] [Batch 3/19] [D loss: 0.000121] [G loss: 1.023976]
# [Epoch 1737/2000] [Batch 4/19] [D loss: 0.000180] [G loss: 1.019974]
# [Epoch 1737/2000] [Batch 5/19] [D loss: 0.000153] [G loss: 1.026431]
# [Epoch 1737/2000] [Batch 6/19] [D loss: 0.000112] [G loss: 1.018490]
# [Epoch 1737/2000] [Batch 7/19] [D loss: 0.000122] [G loss: 1.020669]
# [Epoch 1737/2000] [Batch 8/19] [D loss: 0.000113] [G loss: 1.019094]
# [Epoch 1737/2000] [Batch 9/19] [D loss: 0.000139] [G loss: 1.027924]
# [Epoch 1737/2000] [Batch 10/19] [D loss: 0.000087] [G loss: 1.014815]
# [Epoch 1737/2000] [Batch 11/19] [D loss: 0.000095] [G loss: 1.024340]
# [Epoch 1737/2000] [Batch 12/19] [D loss: 0.000091] [G loss: 1.013727]
# ...

# %%
# Executem l'arxiu main.py per estilitzar una imatge amb un model preentrenat.
# !python style-gan/main.py eval --content-image IMG_20190806_191012.jpg --model style-gan/models/pollock/generator_epoch_1600.pth --output-image output_pollock_1600.jpg --cuda 1
